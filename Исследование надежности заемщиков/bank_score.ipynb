# %%
import pandas as pd


df = pd.read_csv("c:\\Users\\v.ermilov\\.vscode\\Проекты яндекс аналитики\\Исследование надежности заемщиков\\data.csv")

# %%
#смотрим информацию о датасете(типы данных, колличество колонок, и общее число строк)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21525 entries, 0 to 21524
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   children          21525 non-null  int64
#  1   days_employed     19351 non-null  float64
#  2   dob_years         21525 non-null  int64
#  3   education         21525 non-null  object
#  4   education_id      21525 non-null  int64
#  5   family_status     21525 non-null  object
#  6   family_status_id  21525 non-null  int64
#  7   gender            21525 non-null  object
#  8   income_type       21525 non-null  object
#  9   debt              21525 non-null  int64
#  10  total_income      19351 non-null  float64
#  11  purpose           21525 non-null  object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 2.0+ MB

# %%
# первые десять строк как пример
# здесь можно наблюдать непонятные отрицательные значения

df.head(10)
# Out:
#    children  days_employed  dob_years education  education_id  \
# 0         1   -8437.673028         42    высшее             0
# 1         1   -4024.803754         36   среднее             1
# 2         0   -5623.422610         33   Среднее             1
# 3         3   -4124.747207         32   среднее             1
# 4         0  340266.072047         53   среднее             1
# 5         0    -926.185831         27    высшее             0
# 6         0   -2879.202052         43    высшее             0
# 7         0    -152.779569         50   СРЕДНЕЕ             1
# 8         2   -6929.865299         35    ВЫСШЕЕ             0
# 9         0   -2188.756445         41   среднее             1
#
#       family_status  family_status_id gender income_type  debt   total_income  \
# 0   женат / замужем                 0      F   сотрудник     0  253875.639453
# 1   женат / замужем                 0      F   сотрудник     0  112080.014102
# ...

# %%
# проверяем на пустые поля датасет

df.isna().sum()
# Out:
# children               0
# days_employed       2174
# dob_years              0
# education              0
# education_id           0
# family_status          0
# family_status_id       0
# gender                 0
# income_type            0
# debt                   0
# total_income        2174
# purpose                0
# dtype: int64

# %%
# количество дублирующих значений

df.duplicated().sum()
# Out:
# 54

# %%
df.columns
# Out:
# Index(['children', 'days_employed', 'dob_years', 'education', 'education_id',
#        'family_status', 'family_status_id', 'gender', 'income_type', 'debt',
#        'total_income', 'purpose'],
#       dtype='object')

# %%
# по каждому столбцу таблицы выводим информацию об уникальных значениях

for col in df.columns:
    print(f"Уникальные значения < {col} >")
    print(df[col].value_counts())
    print()
# Out:
# Уникальные значения < children >
#  0     14149
#  1      4818
#  2      2055
#  3       330
#  20       76
# -1        47
#  4        41
#  5         9
# Name: children, dtype: int64
#
# Уникальные значения < days_employed >
# -8437.673028      1
# -3507.818775      1
#  354500.415854    1
# -769.717438       1
# -3963.590317      1
#                  ..
# -1099.957609      1
# -209.984794       1
#  398099.392433    1
# -1271.038880      1
# -1984.507589      1
# Name: days_employed, Length: 19351, dtype: int64
#
# Уникальные значения < dob_years >
# 35    617
# 40    609
# 41    607
# 34    603
# 38    598
# 42    597
# 33    581
# 39    573
# 31    560
# 36    555
# 44    547
# 29    545
# 30    540
# 48    538
# 37    537
# 50    514
# 43    513
# 32    510
# 49    508
# 28    503
# 45    497
# 27    493
# 56    487
# 52    484
# 47    480
# 54    479
# 46    475
# 58    461
# 57    460
# 53    459
# 51    448
# 59    444
# 55    443
# 26    408
# 60    377
# 25    357
# ...

# %%
df.describe()
# Out:
#            children  days_employed     dob_years  education_id  \
# count  21525.000000   19351.000000  21525.000000  21525.000000
# mean       0.538908   63046.497661     43.293380      0.817236
# std        1.381587  140827.311974     12.574584      0.548138
# min       -1.000000  -18388.949901      0.000000      0.000000
# 25%        0.000000   -2747.423625     33.000000      1.000000
# 50%        0.000000   -1203.369529     42.000000      1.000000
# 75%        1.000000    -291.095954     53.000000      1.000000
# max       20.000000  401755.400475     75.000000      4.000000
#
#        family_status_id          debt  total_income
# count      21525.000000  21525.000000  1.935100e+04
# mean           0.972544      0.080883  1.674223e+05
# std            1.420324      0.272661  1.029716e+05
# min            0.000000      0.000000  2.066726e+04
# 25%            0.000000      0.000000  1.030532e+05
# 50%            0.000000      0.000000  1.450179e+05
# ...

# %% [markdown]
# На что сразу обращаем внимание:
# * Столбец `children` имеет аномальные значения: 20 и -1.
# * Столбец `days_employed` имеет отрицательные значения, аномальные значения и пропуски.
# * Столбец `dob_years` имеет нулевое значение в 101 раз.
# * Столбец `education` имеет много неявных дубликатов.
# * Столбец `gender` имеет 1 неопределенное значение.
# * Столбец `total_income` имеет пропуски.
# * Столбец `purpose` имеет много неявных дубликатов.
